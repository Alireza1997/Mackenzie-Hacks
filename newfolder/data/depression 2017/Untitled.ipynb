# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df = pd.read_csv('Toronto.csv')

# %%
df.head()
# Out:
#                fullname                  id  likes  replies  retweets  \
# 0  Cpl Ryan W. Voll ret  842547573420425216      0        0         0
# 1   Sayu Healthy Living  844377415820464128      2        1         0
# 2     Justin Roopnarine  846179479731027972      0        0         1
# 3        Deborah Peniuk  850389644592238592      1        0         0
# 4                 Jules  855237562566193152      0        0         0
#
#                                                 text            timestamp  \
# 0  #MentalHealth #Anxiety #Depression #MyLife #Tr...  2017-03-17T01:26:09
# 1  What's eating you?   #stress #depression #anxi...  2017-03-22T02:37:18
# 2  #Depression can happen to anybody. #LetsTalk: ...  2017-03-27T01:58:03
# 3  Today is #WorldHealthDay! #Repost from who #DY...  2017-04-07T16:47:45
# 4  #camh #anxiety #depression #change @ CAMH - Ce...  2017-04-21T01:51:39
#
#               user
# 0  CplRyanWVollRet
# 1      SAYU2Health
# 2      jroopnarine
# 3  TraveliciousDee
# 4   obsessivejules

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
# fullname     13 non-null object
# id           13 non-null int64
# likes        13 non-null int64
# replies      13 non-null int64
# retweets     13 non-null int64
# text         13 non-null object
# timestamp    13 non-null object
# user         13 non-null object
# dtypes: int64(4), object(4)
# memory usage: 912.0+ bytes

# %%
df2 = pd.DataFrame(columns='Count'.split())

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: [Count]
# Index: []

# %%
df2['Count'] = df['text'].str.split(' ', expand=True).stack().value_counts()

# %%
df2.head()
# Out:
#              Count
# #depression      9
# @                5
# #Depression      4
#                  3
# #anxiety         3

# %%
df2.drop(df2.index[[1,3]])
# Out:
#                                            Count
# #depression                                    9
# #Depression                                    4
# #anxiety                                       3
# #toronto                                       3
# to                                             2
# for                                            2
# the                                            2
# is                                             2
# you're                                         2
# can                                            1
# of                                             1
# #gaychub                                       1
# #help.                                         1
# #Anxiety                                       1
# #stress                                        1
# Going                                          1
# #funny                                         1
# #nofiltertshirtco                              1
# #psychotherapy…                                1
# scum                                           1
# http://www.instagram.com.ln.is/hmrPv           1
# day                                            1
# over                                           1
# disability…                                    1
# #supremeleader…                                1
# #culinarychronic                               1
# #problems                                      1
# #healing                                       1
# and                                            1
# #medicine                                      1
# ...                                          ...
# #mentalhealth                                  1
# https://www.instagram.com/p/BTucV-FlaKA/       1
# Krazy                                          1
# https://www.instagram.com/p/BR7IQOvASFS/       1
# #DYK:                                          1
# :)                                             1
# #weather                                       1
# hertZ                                          1
# #stopthestigma                                 1
# #WorldHealthDay!                               1
# #fun                                           1
# be                                             1
# you?                                           1
# Scarborough                                    1
# #TrueStory                                     1
# #psychology                                    1
# #PTSD…                                         1
# #because                                       1
# happen                                         1
# What's                                         1
# #n7                                            1
# #djgimports                                    1
# -                                              1
# #depressed                                     1
# eating                                         1
# #overworked                                    1
# https://www.instagram.com/p/BZz4OvDlUfO/       1
# #MentalHealth                                  1
# #FucKDaWorld                                   1
# North                                          1
#
# [130 rows x 1 columns]

# %%
df2.drop(df2[df2.Count < 2].index, inplace=True)

# %%
df2.head()
# Out:
#         Count
# to          2
# for         2
# the         2
# is          2
# you're      2
